# %%
pip install spotipy
# Out:
#   Cell In[12], line 1
#     pip install Spotify
#         ^
# SyntaxError: invalid syntax

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#This is used for the authentication
client_credentials_manager = SpotifyClientCredentials(client_id= "ff634f96ff334a0795efcd5c89f*****", client_secret="fb1cc9970a6c41338729aebc7fa*****")

# %%
#this is used for the authorization for extracting  data from spotify
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
play_list_link="https://open.spotify.com/playlist/1mQ7GcSB6h6X5RO8QGZanM"

# %%
play_list_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '1mQ7GcSB6h6X5RO8QGZanM']

# %%
play_list_link.split("/")[-1]
# Out:
# '1mQ7GcSB6h6X5RO8QGZanM'

# %%
 play_list_URL=play_list_link.split("/")[-1]

# %%
sp.playlist_tracks( play_list_URL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sp.playlist_tracks( play_list_URL)
#
# NameError: name 'play_list_URL' is not defined

# %%
data=sp.playlist_tracks( play_list_URL)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
len(data['items'])
# Out:
# 41

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Most Popular Best Top Hits Music Mix 2023'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-10-30'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '21XQSGWfYNqUbud3cVTemp'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 18

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp'

# %%
for row in data['items']:
    album_id= row['track']['album']['id']
    album_name= row['track']['album']['name']
    album_release_date= row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url= row['track']['album']['external_urls']['spotify']
    print(album_id)
# Out:
# 21XQSGWfYNqUbud3cVTemp
# 3v4CYcWsvKqwA68YA0yvwr
# 5sJzh97GKQt5JeeztK8xtH
# 6N8O1hZXvuZ8GDl72RDQA1
# 0syejzGSMpdlyg7DdUlcyH
# 0tpURyoQhfzHVKLgL9hMzt
# 4hMuNlBZellaJAVAPk7DIq
# 2KqmWGLMdwozfQDLUjubhV
# 0W3lKltRJp5Kx3h8aaLeBc
# 4rmMIaup0Qx0x2UMrLohMl
# 5yvoBNgrgkVQHADrEWEptM
# 1bGJMMaHig8sMb4xZM837j
# 5boGxspenzva86OKCkzS9B
# 7oEohUhDElayhZ0gHQrzgT
# 6aSlxzHYrnwefm0rc53V64
# 38EvL0BXMMcw9knOWRg0bq
# 2FtA8uyX5b8Q4ToB4Wxx3W
# 1WECek4D8HgDFZz9xgbibz
# 2bU09cMzTUPn69Z42GP9zO
# 4kXWTQXYO9uOSIEFGAEITg
# 0Z8nTWZg7jCZcxmRz6E0iu
# 0zhWdq4FJWxUKJseoKcY8B
# 1jGDVsAKMyqvvaLzK6PgyZ
# 1rSZzPr2abjqS6EIvLNJKk
# 6KndRkAQsWTlXzBhjST0PG
# 1QD5zXrLP6UYSSK08syUAG
# 4UQ1ZlWdsMshMTacrM3uIy
# 18RhOyAka5HGWVzth8JzF3
# 7kXJwfPmkPAU9HwWS3iENI
# 5WzApm7SntudZT6mfXJP98
# 4nB4lTfIr04tMZNibydZUO
# 33GIACo1vP9mPSFqQVuNTy
# 6aBMJFDPqgXRdsC7hThC68
# 3RMkWQKFCkU7LuzQWni0s8
# 1k3qchMbve4oYv3Ys1dy7b
# 5LR8IMzCIz6lo70EIAEhrt
# 2RjMaKO3FbVnG019iPwaCn
# 5InjXAxHwEjzZX9iAtt5c2
# 6N306GBzoUoScBklrbZSyp
# 4zk0IqIUCMKpxSykO0VxOS
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    print(album_id)
    print(album_name)
    print(album_release_date)
    print(album_total_tracks)
    print(album_url)
# Out:
# 21XQSGWfYNqUbud3cVTemp
# Most Popular Best Top Hits Music Mix 2023
# 2023-10-30
# 18
# https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp
# 3v4CYcWsvKqwA68YA0yvwr
# FREEDOM
# 2022-03-04
# 23
# https://open.spotify.com/album/3v4CYcWsvKqwA68YA0yvwr
# 5sJzh97GKQt5JeeztK8xtH
# Lofi Loop Chillhop Mix 8
# 2022-10-04
# 10
# https://open.spotify.com/album/5sJzh97GKQt5JeeztK8xtH
# 6N8O1hZXvuZ8GDl72RDQA1
# Lofi Beyond with Dispirited Ocean
# 2022-07-16
# 2
# https://open.spotify.com/album/6N8O1hZXvuZ8GDl72RDQA1
# 0syejzGSMpdlyg7DdUlcyH
# Neon Lights
# 2023-11-03
# 10
# https://open.spotify.com/album/0syejzGSMpdlyg7DdUlcyH
# 0tpURyoQhfzHVKLgL9hMzt
# dreams
# 2020-04-28
# 6
# https://open.spotify.com/album/0tpURyoQhfzHVKLgL9hMzt
# 4hMuNlBZellaJAVAPk7DIq
# Movie Night
# 2023-05-30
# 1
# https://open.spotify.com/album/4hMuNlBZellaJAVAPk7DIq
# 2KqmWGLMdwozfQDLUjubhV
# Le son du jazz
# 2021-06-07
# 1
# https://open.spotify.com/album/2KqmWGLMdwozfQDLUjubhV
# 0W3lKltRJp5Kx3h8aaLeBc
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element={
        'album_id':album_id,
        'album_name':album_name,
        'release_date':album_release_date,
        'total_tracks':album_total_tracks,
        'url':album_url}
    print(album_element)
# Out:
# {'album_id': '21XQSGWfYNqUbud3cVTemp', 'album_name': 'Most Popular Best Top Hits Music Mix 2023', 'release_date': '2023-10-30', 'total_tracks': 18, 'url': 'https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp'}
# {'album_id': '3v4CYcWsvKqwA68YA0yvwr', 'album_name': 'FREEDOM', 'release_date': '2022-03-04', 'total_tracks': 23, 'url': 'https://open.spotify.com/album/3v4CYcWsvKqwA68YA0yvwr'}
# {'album_id': '5sJzh97GKQt5JeeztK8xtH', 'album_name': 'Lofi Loop Chillhop Mix 8', 'release_date': '2022-10-04', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/5sJzh97GKQt5JeeztK8xtH'}
# {'album_id': '6N8O1hZXvuZ8GDl72RDQA1', 'album_name': 'Lofi Beyond with Dispirited Ocean', 'release_date': '2022-07-16', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/6N8O1hZXvuZ8GDl72RDQA1'}
# {'album_id': '0syejzGSMpdlyg7DdUlcyH', 'album_name': 'Neon Lights', 'release_date': '2023-11-03', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/0syejzGSMpdlyg7DdUlcyH'}
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    album_element = {
        'album_id': album_id,
        'album_name': album_name,
        'release_date': album_release_date,
        'total_tracks': album_total_tracks,
        'url': album_url
    }
    
    print(album_element)
# Out:
# {'album_id': '21XQSGWfYNqUbud3cVTemp', 'album_name': 'Most Popular Best Top Hits Music Mix 2023', 'release_date': '2023-10-30', 'total_tracks': 18, 'url': 'https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp'}
# {'album_id': '3v4CYcWsvKqwA68YA0yvwr', 'album_name': 'FREEDOM', 'release_date': '2022-03-04', 'total_tracks': 23, 'url': 'https://open.spotify.com/album/3v4CYcWsvKqwA68YA0yvwr'}
# {'album_id': '5sJzh97GKQt5JeeztK8xtH', 'album_name': 'Lofi Loop Chillhop Mix 8', 'release_date': '2022-10-04', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/5sJzh97GKQt5JeeztK8xtH'}
# {'album_id': '6N8O1hZXvuZ8GDl72RDQA1', 'album_name': 'Lofi Beyond with Dispirited Ocean', 'release_date': '2022-07-16', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/6N8O1hZXvuZ8GDl72RDQA1'}
# {'album_id': '0syejzGSMpdlyg7DdUlcyH', 'album_name': 'Neon Lights', 'release_date': '2023-11-03', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/0syejzGSMpdlyg7DdUlcyH'}
# ...

# %%
album_list= []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    album_element = {
        'album_id': album_id,
        'album_name': album_name,
        'release_date': album_release_date,
        'total_tracks': album_total_tracks,
        'url': album_url
    }
    
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '21XQSGWfYNqUbud3cVTemp',
#   'album_name': 'Most Popular Best Top Hits Music Mix 2023',
#   'release_date': '2023-10-30',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/21XQSGWfYNqUbud3cVTemp'},
#  {'album_id': '3v4CYcWsvKqwA68YA0yvwr',
#   'album_name': 'FREEDOM',
#   'release_date': '2022-03-04',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3v4CYcWsvKqwA68YA0yvwr'},
#  {'album_id': '5sJzh97GKQt5JeeztK8xtH',
#   'album_name': 'Lofi Loop Chillhop Mix 8',
#   'release_date': '2022-10-04',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/5sJzh97GKQt5JeeztK8xtH'},
#  {'album_id': '6N8O1hZXvuZ8GDl72RDQA1',
#   'album_name': 'Lofi Beyond with Dispirited Ocean',
#   'release_date': '2022-07-16',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6N8O1hZXvuZ8GDl72RDQA1'},
#  {'album_id': '0syejzGSMpdlyg7DdUlcyH',
#   'album_name': 'Neon Lights',
#   'release_date': '2023-11-03',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MGnOdzzXNoGcUgfxMcSwA'},
#   'href': 'https://api.spotify.com/v1/artists/6MGnOdzzXNoGcUgfxMcSwA',
#   'id': '6MGnOdzzXNoGcUgfxMcSwA',
#   'name': 'Todays Top Hits',
#   'type': 'artist',
#   'uri': 'spotify:artist:6MGnOdzzXNoGcUgfxMcSwA'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7haeSqCyAAF7Zw5XRAllvJ'},
#   'href': 'https://api.spotify.com/v1/artists/7haeSqCyAAF7Zw5XRAllvJ',
#   'id': '7haeSqCyAAF7Zw5XRAllvJ',
#   'name': 'Top Hits Today',
#   'type': 'artist',
#   'uri': 'spotify:artist:7haeSqCyAAF7Zw5XRAllvJ'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-06-15T20:31:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31w3nz62oad6gsf6fhbstzjxjpbi'},
#   'href': 'https://api.spotify.com/v1/users/31w3nz62oad6gsf6fhbstzjxjpbi',
#   'id': '31w3nz62oad6gsf6fhbstzjxjpbi',
#   'type': 'user',
#   'uri': 'spotify:user:31w3nz62oad6gsf6fhbstzjxjpbi'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bdccd099e36afa96ffda1530ae3b86989bf28cfa?cid=ff634f96ff334a0795efcd5c89f50ae8',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '6MGnOdzzXNoGcUgfxMcSwA'

# %%
for row in data['items']:
    for key, value in row.items():
        if key =='track':
            print(value)
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/bdccd099e36afa96ffda1530ae3b86989bf28cfa?cid=ff634f96ff334a0795efcd5c89f50ae8', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key =='track':
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MGnOdzzXNoGcUgfxMcSwA'}, 'href': 'https://api.spotify.com/v1/artists/6MGnOdzzXNoGcUgfxMcSwA', 'id': '6MGnOdzzXNoGcUgfxMcSwA', 'name': 'Todays Top Hits', 'type': 'artist', 'uri': 'spotify:artist:6MGnOdzzXNoGcUgfxMcSwA'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7haeSqCyAAF7Zw5XRAllvJ'}, 'href': 'https://api.spotify.com/v1/artists/7haeSqCyAAF7Zw5XRAllvJ', 'id': '7haeSqCyAAF7Zw5XRAllvJ', 'name': 'Top Hits Today', 'type': 'artist', 'uri': 'spotify:artist:7haeSqCyAAF7Zw5XRAllvJ'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2VfivUm19U6rmx8GwzUFtD'}, 'href': 'https://api.spotify.com/v1/artists/2VfivUm19U6rmx8GwzUFtD', 'id': '2VfivUm19U6rmx8GwzUFtD', 'name': 'The Last Nation', 'type': 'artist', 'uri': 'spotify:artist:2VfivUm19U6rmx8GwzUFtD'}]
# ...

# %%
artist_list=[]
for row in data['items']:
    for key, value in row.items():
        if key =='track':
            for artist in value ['artists']:
                artist_dict={'artists_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artists_id': '6MGnOdzzXNoGcUgfxMcSwA',
#   'artist_name': 'Todays Top Hits',
#   'external_url': 'https://api.spotify.com/v1/artists/6MGnOdzzXNoGcUgfxMcSwA'},
#  {'artists_id': '7haeSqCyAAF7Zw5XRAllvJ',
#   'artist_name': 'Top Hits Today',
#   'external_url': 'https://api.spotify.com/v1/artists/7haeSqCyAAF7Zw5XRAllvJ'},
#  {'artists_id': '2VfivUm19U6rmx8GwzUFtD',
#   'artist_name': 'The Last Nation',
#   'external_url': 'https://api.spotify.com/v1/artists/2VfivUm19U6rmx8GwzUFtD'},
#  {'artists_id': '66Vc6No6gQJ5bZvs9uCw9L',
#   'artist_name': 'Chiller Loop',
#   'external_url': 'https://api.spotify.com/v1/artists/66Vc6No6gQJ5bZvs9uCw9L'},
#  {'artists_id': '2vpE7WMWRYohCfJ7uU7gr6',
#   'artist_name': 'Chillhop Loop',
#   'external_url': 'https://api.spotify.com/v1/artists/2vpE7WMWRYohCfJ7uU7gr6'},
#  {'artists_id': '5O6N5WthVbUXGXyvZ16MCo',
#   'artist_name': 'STUDIO BEYOND',
#   'external_url': 'https://api.spotify.com/v1/artists/5O6N5WthVbUXGXyvZ16MCo'},
# ...

# %%
song_list=[]
for row in data['items']:
    song_id = row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['artists']
    artist_id=row['track']['album']['artists'][0]['id']
    # creat a dictionary for the current album
    song_elements={
        'song_id':song_id,
        'song_name':song_name,
        'duration_ms':song_duration,
        'url':song_url,
        'popularity':song_popularity,
        'song_added':song_added,
        'album_id':album_id,
        'artist_id':artist_id}
    song_list.append(song_elements)

# %%
import pandas as pd

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                 album_name  \
# 0  21XQSGWfYNqUbud3cVTemp  Most Popular Best Top Hits Music Mix 2023
# 1  3v4CYcWsvKqwA68YA0yvwr                                    FREEDOM
# 2  5sJzh97GKQt5JeeztK8xtH                   Lofi Loop Chillhop Mix 8
# 3  6N8O1hZXvuZ8GDl72RDQA1          Lofi Beyond with Dispirited Ocean
# 4  0syejzGSMpdlyg7DdUlcyH                                Neon Lights
#
#   release_date  total_tracks  \
# 0   2023-10-30            18
# 1   2022-03-04            23
# 2   2022-10-04            10
# 3   2022-07-16             2
# 4   2023-11-03            10
#
#                                                  url
# 0  https://open.spotify.com/album/21XQSGWfYNqUbud...
# 1  https://open.spotify.com/album/3v4CYcWsvKqwA68...
# 2  https://open.spotify.com/album/5sJzh97GKQt5Jee...
# 3  https://open.spotify.com/album/6N8O1hZXvuZ8GDl...
# 4  https://open.spotify.com/album/0syejzGSMpdlyg7...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      41 non-null     object
#  1   album_name    41 non-null     object
#  2   release_date  41 non-null     object
#  3   total_tracks  41 non-null     int64
#  4   url           41 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.7+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
#song DataFrame
song_df=pd.DataFrame.from_dict(song_list)

# %%
artist_df=pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                artists_id      artist_name  \
# 0  6MGnOdzzXNoGcUgfxMcSwA  Todays Top Hits
# 1  7haeSqCyAAF7Zw5XRAllvJ   Top Hits Today
# 2  2VfivUm19U6rmx8GwzUFtD  The Last Nation
# 3  66Vc6No6gQJ5bZvs9uCw9L     Chiller Loop
# 4  2vpE7WMWRYohCfJ7uU7gr6    Chillhop Loop
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6MGnOdzzXNo...
# 1  https://api.spotify.com/v1/artists/7haeSqCyAAF...
# 2  https://api.spotify.com/v1/artists/2VfivUm19U6...
# 3  https://api.spotify.com/v1/artists/66Vc6No6gQJ...
# 4  https://api.spotify.com/v1/artists/2vpE7WMWRYo...

# %%
 artist_df=artist_df.drop_duplicates(subset=['artist_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 artist_df=artist_df.drop_duplicates(subset=['artist_id'])
#
# NameError: name 'artist_df' is not defined

# %%
song_df.head(10)
# Out:
#                   song_id                   song_name  duration_ms  \
# 0  2RIhkPE1O18j2xVDJgrwqG              2023 Hit Songs       124683
# 1  5rjzJ6eLl1jbJP5mbMIZP1              Everything Bad       176295
# 2  1iyWqQVJLM4K6jMu4cgi6U  Loop Chillhop Music Pt. 77        82894
# 3  2uY8algW7nacTERI4hfMYq             The Love Search       193800
# 4  0WDjvCQ1u38qhRoQWjP890         COFFEE SHOP MORNING       130481
# 5  5w54ZhkINqM21sOhdLNR0I                  junglebook       116412
# 6  0odsjxvPUug5zOMxhITmrx                 Movie Night       196626
# 7  3VFbDfjkyWlJNYXdSCKPCV              Le son du jazz        69606
# 8  2FzDs3kEMnFhbCT3eNusd4  Calming Chill Gaming Music        57648
# 9  6iV9n9bdUideqWPqfodEtd                        Rose       175180
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2RIhkPE1O18j2xV...           6
# 1  https://open.spotify.com/track/5rjzJ6eLl1jbJP5...          15
# ...

# %%
album_df.head()
# Out:
#                  album_id                                 album_name  \
# 0  21XQSGWfYNqUbud3cVTemp  Most Popular Best Top Hits Music Mix 2023
# 1  3v4CYcWsvKqwA68YA0yvwr                                    FREEDOM
# 2  5sJzh97GKQt5JeeztK8xtH                   Lofi Loop Chillhop Mix 8
# 3  6N8O1hZXvuZ8GDl72RDQA1          Lofi Beyond with Dispirited Ocean
# 4  0syejzGSMpdlyg7DdUlcyH                                Neon Lights
#
#   release_date  total_tracks  \
# 0   2023-10-30            18
# 1   2022-03-04            23
# 2   2022-10-04            10
# 3   2022-07-16             2
# 4   2023-11-03            10
#
#                                                  url
# 0  https://open.spotify.com/album/21XQSGWfYNqUbud...
# 1  https://open.spotify.com/album/3v4CYcWsvKqwA68...
# 2  https://open.spotify.com/album/5sJzh97GKQt5Jee...
# 3  https://open.spotify.com/album/6N8O1hZXvuZ8GDl...
# 4  https://open.spotify.com/album/0syejzGSMpdlyg7...

# %%
album_df['release_date'] =pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      41 non-null     object
#  1   album_name    41 non-null     object
#  2   release_date  41 non-null     datetime64[ns]
#  3   total_tracks  41 non-null     int64
#  4   url           41 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.7+ KB

# %%
song_df['song added'] =pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id                   song_name  duration_ms  \
# 0  2RIhkPE1O18j2xVDJgrwqG              2023 Hit Songs       124683
# 1  5rjzJ6eLl1jbJP5mbMIZP1              Everything Bad       176295
# 2  1iyWqQVJLM4K6jMu4cgi6U  Loop Chillhop Music Pt. 77        82894
# 3  2uY8algW7nacTERI4hfMYq             The Love Search       193800
# 4  0WDjvCQ1u38qhRoQWjP890         COFFEE SHOP MORNING       130481
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2RIhkPE1O18j2xV...           6
# 1  https://open.spotify.com/track/5rjzJ6eLl1jbJP5...          15
# 2  https://open.spotify.com/track/1iyWqQVJLM4K6jM...          17
# 3  https://open.spotify.com/track/2uY8algW7nacTER...           1
# 4  https://open.spotify.com/track/0WDjvCQ1u38qhRo...          35
#
#              song_added                                           album_id  \
# 0  2024-06-15T20:31:05Z  [{'external_urls': {'spotify': 'https://open.s...
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      41 non-null     object
#  1   song_name    41 non-null     object
#  2   duration_ms  41 non-null     int64
#  3   url          41 non-null     object
#  4   popularity   41 non-null     int64
#  5   song_added   41 non-null     object
#  6   album_id     41 non-null     object
#  7   artist_id    41 non-null     object
#  8   song added   41 non-null     datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(6)
# memory usage: 3.0+ KB
